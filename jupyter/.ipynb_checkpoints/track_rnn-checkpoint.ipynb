# %%
import pickle
import json
import numpy as np
from scipy import interpolate
from sklearn.manifold import TSNE
import math
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from matplotlib import rc
rc('text', usetex=True)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import seaborn as sns
# sns.set_context("paper")
sns.set()
sns.set_context('talk')
import pandas as pd 
from scipy.stats import entropy
from scipy.interpolate import spline
from  matplotlib.gridspec import GridSpecFromSubplotSpec as gsub
from  matplotlib.gridspec import GridSpec as gr

# %matplotlib inline

# %%
baseline = pickle.load(open('../Results/baseline_track.tr', 'rb'))
word_idf_a09 = pickle.load(open('../Results/word2_tword015_CocoGlove_idf_bis_a09_track.tr', 'rb'))
word_a08 = pickle.load(open('../Results/word2_tword015_coco_a08_showtell_resnet50_track.tr', 'rb'))
topdown_a03 = pickle.load(open('../Results/word2_coco_tword017_a03_topdown_resnet152_msc_track.tr', 'rb'))
fn_topdown_a03 = pickle.load(open('../Results/fncnn6_word2_coco_tword017_a03_topdown_resnet152_msc_track.tr', 'rb'))
topdown_a09= pickle.load(open('../Results/word2_coco_tword009_a09_topdown_resnet152_msc_track.tr', 'rb'))
fn_topdown_a03_dir = pickle.load(open('../Results/fncnn6_word2_coco_tword017_a03_topdown_resnet152_msc_track_dirac.tr', 'rb'))
topdown_a09_dir = pickle.load(open('../Results/word2_coco_tword009_a09_topdown_resnet152_msc_track_dirac.tr', 'rb'))

# %%
def plot_distribs(stats, out, nim=3, th=1e-7):
    model = stats["probas"][0]
    reward  = stats["rewards"][0]
    sns.set()
    N , S, V = model.shape
    S = min(S, 9)
    N = min(N, nim)
    colors = sns.color_palette("Set2", S)
    fig = plt.figure(figsize=(14, 8*N))
    outer = gr(N, 1, wspace=0.2, hspace=0.2)
    for n in range(N):
        en = 0
        kl = 0
        inner = gsub(S, 1,
                     subplot_spec=outer[n],
                     wspace=1, hspace=0.1)

        for c in range(S):
            ax = plt.Subplot(fig, inner[c])
#             indices = np.arange(len(model[0, 0]))
            indices = np.array([x for x in range(len(model[0, 0])) if model[n,c,x] > th or reward[n,c,x] > th])
#             ax.plot(indices, model[n, c, indices], '-^', c=colors[c], alpha=.5, ms=2, lw=.4)
#             ax.plot(indices, reward[n, c, indices],'-o', c=colors[c], alpha=.5, ms=2, lw=.4, ls='--')
            print('ind:', indices)
            ax.bar(indices, model[n, c, indices], color=colors[c], alpha=1, width=1, align="edge")
            ax.bar(indices+.5, reward[n, c, indices], color=colors[c], alpha=1, width=1, align='edge')
            kl  = entropy(reward[n, c, :], model[n, c, :])
            en  = entropy(model[n, c, :])
            ax.set_title('t = %d, KL=%.2f, $H(p_\\theta$)=%.2f' % (c, kl, en), fontsize=7)
            fig.add_subplot(ax)    
#     plt.legend(ncol=4)
    plt.savefig('../figures/%s_distrib.png' % out,
                dpi=300, bbox_inches='tight')

# %%
def plot_distribs_mat(stats, out, nim=3):
    model = stats["probas"][0]
    reward  = stats["rewards"][0]
    sns.set()
    N , S, V = model.shape
    S = min(S, 9)
    N = min(N, nim)
    colors = sns.color_palette("Set2", S)
    f, axs = plt.subplots(2*N, 1, figsize=(18, 2 * N))
    for n in range(N):
        kl = 0
        en = 0
        for c in range(1, S):
            kl  += entropy(reward[n, c, :], model[n, c, :])
            en  += entropy(model[n, c, :])
        kl /= (S-1)
        en /= (S-1)
        sns.heatmap(model[n, 1:S], annot=False, fmt=".2f", cmap="YlGnBu",
                    vmax=1e-3, vmin=1e-7, ax=axs[2*n])
        sns.heatmap(reward[n, 1:S], annot=False, fmt=".2f", cmap="YlGnBu",
                    vmax=1, vmin=.8, ax=axs[2*n+1])
        axs[2*n].set_title('mean KL=%.2f, mean $H(p_\\theta$)=%.2f' % (kl, en))
    # plt.legend(ncol=4)
    plt.savefig('../figures/%s_distrib_mat.png' % out,
                dpi=300, bbox_inches='tight')

# %%
plot_distribs_mat(baseline, 'ml_showtell')

# %%
plot_distribs(baseline, 'ml_showtell', nim=1, th=1e-3)
# Out:
# ind: [1125 1311 1975 2015 2423 2597 3029 4270 4410 4465 4709 4936 5134 5366 5530
#  5595 6178 7543 7961 8035 8128 8174 8325 8536 9359 9487]
# ind: [ 115  309  429  739  902  919 1281 1845 1892 2402 2671 3009 3199 3240 3253
#  3781 4050 4465 4607 5001 5081 5134 6049 6584 7045 7373 8128 8174 8430 9084
#  9359 9487]
# ind: [ 110  224  269  290  296  349  480  532  632  702  943  966 1086 1197 1419
#  1425 1603 1783 1955 2052 2209 2262 2530 2599 2625 2792 2936 3215 3630 3636
#  3738 4208 4624 5083 5148 5241 5481 5847 6394 6573 6606 6822 6969 7094 7221
#  7345 7492 7538 7599 7786 7826 7857 8309 8875 8947 9196 9402 9471 9487]
# ind: [ 108  702 1311 2189 2517 2597 2898 3029 3987 4270 4614 4709 4936 4972 5001
#  5117 5595 5750 6178 6502 7386 7961 8035 8325 9196 9267 9487]
# ind: [   8   61  111  154  309  332  429  483  516  700  737  902  906  919  934
#   987  997 1205 1243 1280 1281 1301 1391 1396 1714 2017 2059 2143 2173 2247
#  2286 2302 2323 2366 2402 2502 2671 2759 2804 2841 2934 2966 2975 3009 3140
#  3217 3240 3426 3659 3690 3750 3781 3987 3990 4025 4050 4062 4220 4319 4358
#  4411 4420 4607 4613 4666 4721 4859 4867 4935 5001 5134 5274 5595 5666 5720
#  5772 5779 5781 5842 5954 6049 6152 6178 6218 6280 6407 6470 6902 7045 7062
#  7073 7604 7791 7939 7943 8128 8174 8264 8310 8311 8315 8430 8661 8777 8784
#  9032 9083 9084 9206 9215 9386 9467 9487]
# ind: [  63   72  111  224  483  700  902  934  944 1280 1281 1311 1657 1692 1854
#  1958 1978 2012 2102 2173 2189 2288 2402 2476 2530 2784 2792 2804 2841 2889
#  2934 2937 3009 3140 3217 3219 3251 3487 3630 3659 3690 3742 3750 3770 3781
#  3853 3872 3986 3987 3998 4025 4050 4296 4358 4439 4613 4755 4908 4935 4994
#  5113 5117 5274 5366 5377 5435 5457 5595 5665 5666 5720 5772 5779 5804 5954
#  5992 6021 6407 6470 6505 6506 6778 6834 6928 7045 7067 7091 7345 7578 7791
#  7943 8012 8116 8144 8174 8264 8311 8315 8430 8470 8543 8777 8784 8789 8873
#  8912 9032 9083 9084 9196 9203 9215 9386 9450 9487]
# ind: [ 111  290  296  442  480  644  702  907 1353 1419 1463 1688 1741 1809 2425
#  2530 2598 2599 2744 2792 2936 2937 3166 3215 3311 3630 3636 3787 4624 4834
#  4839 4890 4957 4981 4993 5117 5241 5481 5520 5593 5618 5847 6683 6822 6969
#  7273 7345 7857 7961 8012 8035 8309 8912 9196 9471]
# ind: [  79  107  108  110  111  219  349  480  532  644 1281 1311 1419 1741 1809
#  1955 1975 2402 2418 2423 2517 2530 2597 2792 2804 2841 2936 3009 3029 3140
#  3235 3630 3636 3738 4270 4296 4624 4701 4834 4936 4972 5001 5241 5366 5481
#  5568 5595 5618 5666 5779 5847 6178 6394 6407 6470 6573 6606 6808 6822 7045
#  7345 7386 7555 7599 7791 7961 8006 8035 8128 8264 8309 8325 8575 8661 8707
#  8875 8947 9267 9471 9487]
# ind: [   0  219  644  702 2423 2597 2599 2970 3029 3140 3632 3636 3750 3781 3987
#  4270 4296 4614 4936 4972 5366 5595 6178 7386 7961 8035 8105 8325 9267]

# %%
plot_distribs(word_idf_a09, 'word_t015_idf_a09_showtell')

# %%
plot_distribs(word_a08, 'word_t015_a08_showtell')

# %%
plot_distribs(topdown_a03, 'word_t017_a03_topdown')

# %%
plot_distribs(fn_topdown_a03, 'fn_word_t017_a03_topdown')

# %%
plot_distribs(topdown_a09, 'word_t009_a09_topdown')

# %%
plot_distribs(topdown_a09_dir, 'word_t009_a09_dir_topdown')

# %%
plot_distribs(fn_topdown_a03_dir, 'fn_word_t017_a03_dir_topdown')
