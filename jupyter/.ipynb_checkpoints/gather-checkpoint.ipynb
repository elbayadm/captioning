# %%
import glob
import operator
import pickle
from math import exp
from prettytable import PrettyTable

# %%
def get_results(model, split='val'):
    model_dir = model
    val_results = glob.glob('%s/val_*.res' % model_dir)
    compiled = []
    for res in val_results:
        params = res.split('/')[-1].split('_')
        beam = int(params[1][2:])
        sample_max = 1 if params[3] == "max" else 0
        temp = 0
        if not sample_max:
            temp = float(params[4])
            index = 5
        else:
            index = 4
        flip = int(params[index][4])
        params = {'beam_size': beam, 'sample_max': sample_max,
                 'temperature': temp, 'flip': flip}
        # Load results:
        out = pickle.load(open(res, 'rb'))
        compiled.append([params, out])
    return compiled

# %%
fields = ['Beam', 'Temperature', 'CIDEr', 'Bleu4', 'Spice', 'Perplexity']
def gather_results(model):
    outputs = get_results(model)
    tab = PrettyTable()
    tab.field_names = ['Sorter'] + fields
    for (p, res) in outputs:
        tab.add_row([p['beam_size'] + p['temperature'],
                     p['beam_size'], p['temperature'],
                     round(res['CIDEr'] * 100, 2), round(res['Bleu_4'] * 100, 2),
                     round(res['SPICE'] * 100, 2), round(exp(res['ml_loss']), 2)])
    return tab

# %%
tab = gather_results("../save/baseline")
print(tab.get_string(fields=fields, sortby="Sorter"))
print(tab.get_html_string(fields=fields, sortby="Sorter"))
# Out:
# +------+-------------+-------+-------+-------+------------+
# | Beam | Temperature | CIDEr | Bleu4 | Spice | Perplexity |
# +------+-------------+-------+-------+-------+------------+
# |  1   |      0      | 77.78 |  24.6 | 15.22 |   10.78    |
# |  1   |     0.05    | 77.33 | 24.38 | 15.17 |   10.78    |
# |  1   |     0.1     | 76.94 |  24.4 | 15.13 |   10.78    |
# |  1   |     0.5     | 66.54 | 20.16 | 13.88 |   10.78    |
# |  1   |     0.8     | 50.42 | 14.29 | 12.03 |   10.78    |
# |  1   |     1.0     | 37.54 |  9.81 | 10.15 |   10.78    |
# |  2   |      0      | 80.38 | 26.45 | 15.71 |   10.78    |
# |  3   |      0      |  80.0 | 26.51 | 15.69 |   10.78    |
# |  4   |      0      | 79.75 | 26.44 | 15.59 |   10.78    |
# |  5   |      0      | 79.71 | 26.54 | 15.53 |   10.78    |
# |  6   |      0      | 79.48 | 26.44 | 15.47 |   10.78    |
# +------+-------------+-------+-------+-------+------------+
# <table>
#     <tr>
#         <th>Beam</th>
#         <th>Temperature</th>
#         <th>CIDEr</th>
#         <th>Bleu4</th>
#         <th>Spice</th>
#         <th>Perplexity</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0</td>
#         <td>77.78</td>
#         <td>24.6</td>
#         <td>15.22</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.05</td>
#         <td>77.33</td>
#         <td>24.38</td>
#         <td>15.17</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.1</td>
#         <td>76.94</td>
#         <td>24.4</td>
#         <td>15.13</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.5</td>
#         <td>66.54</td>
#         <td>20.16</td>
#         <td>13.88</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.8</td>
#         <td>50.42</td>
#         <td>14.29</td>
#         <td>12.03</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>1.0</td>
#         <td>37.54</td>
#         <td>9.81</td>
#         <td>10.15</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>0</td>
#         <td>80.38</td>
#         <td>26.45</td>
#         <td>15.71</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>0</td>
#         <td>80.0</td>
#         <td>26.51</td>
#         <td>15.69</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>0</td>
#         <td>79.75</td>
#         <td>26.44</td>
#         <td>15.59</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>0</td>
#         <td>79.71</td>
#         <td>26.54</td>
#         <td>15.53</td>
#         <td>10.78</td>
#     </tr>
#     <tr>
#         <td>6</td>
#         <td>0</td>
#         <td>79.48</td>
#         <td>26.44</td>
#         <td>15.47</td>
#         <td>10.78</td>
#     </tr>
# </table>

# %%
def crawl_results():
    models = glob.glob('../save/*')
    print("Found:", models)
    for model in models:
